# %% [markdown]
# # My Hack: Classifying mergers in Eagle simulations

# %% [markdown]
# What are eagle simulations?
# why eagle?
# long term goal
# short term goal

# %% [markdown]
# ## Classifying mergers by their Size and Mass Ratio

# %% [markdown]
# ### Training set

# %% [markdown]
# <img src="Images/EM.png" width=800 height=800 />

# %% [markdown]
# ### Procedure

# %% [markdown]
# <img src="Images/classification.png" width=800 height=800 />

# %% [markdown]
# Links to the data - https://drive.google.com/drive/folders/1AMv2tWMj11mR5O2KA86Ab4z9XQZRBD5r?usp=sharing

# %% [markdown]
# ## Code

# %%
import numpy as np
import os
from PIL import Image
import h5py
from sklearn.model_selection import train_test_split

# %%
def data(Ipath, N, parameter): 
    
    """Retrieving the galaxy merger images and their corresponding labels of size and mass ratio
    
    i/p params:
    
    path - path of the images and labels
    N - number of images we want in the training set
    parameter - Mass/Size ratio 
    
    o/p params:
    
    X - an np 3D array of randomly picked 'N' galaxy merger images. The 3D is to comply with the dimensional 
    requirement of the neural network. Here, the images are black and white so all 3 dimensions are the same. 
    Y - labels 
    """
    
    X =[]
    Y = np.array([])
    redshift=[]
    merger=[]
    
    for path, subdirs, image_names in os.walk(Ipath+ 'Data/eagle_images'):
        image_names=np.array(image_names)
        imgs= np.array([img for img in image_names if img.split('_')[3]== '0.jpg'])
        ind = np.random.choice(np.arange(len(imgs)),N)                  #indices of N randomly picked images 
        picked_image_names = imgs[ind]                                  #images pertaining to these indices

        for i, name in enumerate(picked_image_names):
            img_path = os.path.join(path,name)
            img_pixels = np.array(Image.open(img_path).getdata())
            X.append(img_pixels)
            redshift.append(int(name.split('_')[1]))
            merger.append(int(name.split('_')[2]))
            f= h5py.File(Ipath+'Data/mergers_identified/mergers_'+str(int(redshift[-1]))+'.hdf5', 'r')
            Y=list(np.append(Y,f.get(parameter).value[int(merger[-1])]))

    
    X=np.array(X)
    X=X.reshape((len(Y),224,224,3))
    Y=np.array(Y)
    
    return X,Y

# %%
Ipath = '/home/malavika/MyHackmain/'
X, Y = data(Ipath, 100, parameter= 'Size Ratio')
X= X[:,:,:,:1]
# Out:
# /home/malavika/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.

# %%
print(np.shape(X))
print(np.shape(Y))
# Out:
# (100, 224, 224, 1)
# (100,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33)#, random_state=seed)

# %%
print(len(X_train))
print(len(X_test))
print(len(Y_train))
print(len(Y_test))
# Out:
# 67
# 33
# 67
# 33

# %%
X_train=np.array(X_train)
Y_train=np.array(Y_train)
X_test=np.array(X_test)
Y_test=np.array(Y_test)

# %% [markdown]
# ## Training

# %%
import tensorflow
from tensorflow.python.keras import layers 
from tensorflow.python.keras.losses import categorical_crossentropy
from tensorflow.python.keras.callbacks import TensorBoard
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Model
from tensorflow.python.keras import backend
from tensorflow.keras.models import load_model
from keras.utils import CustomObjectScope
from tensorflow.python.keras import optimizers
from tensorflow.python.keras.callbacks import ModelCheckpoint
from keras.metrics import top_k_categorical_accuracy

from keras.models import Sequential 
from keras.layers import Dense
from tensorflow.keras import layers,models
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from keras.utils import to_categorical

# %%
Yround_train= np.array([])
Yround_test= np.array([]) 

cl=[0,0.25,0.5,0.75,1.0,1.25]

Y_train_ohe = np.zeros((len(Y_train), 5), dtype=np.int)
Y_test_ohe= np.zeros((len(Y_test), 5), dtype=np.int)

for i in np.arange(len(Y_train)):
    for j in np.arange(1,len(cl)):
        if Y_train[i]> cl[j-1] and  Y_train[i]< cl[j]: 
            Yround_train=np.append(Yround_train,cl[j])
            Y_train_ohe[i, j-1] = 1

for i in np.arange(len(Y_test)):
    for j in np.arange(1,len(cl)):
        if Y_test[i]> cl[j-1] and  Y_test[i]< cl[j]: 
            Yround_test=np.append(Yround_test,cl[j])
            Y_test_ohe[i, j-1] = 1

# %%
#Yround_train,Yround_test, Y_train_ohe, Y_test_ohe

# %%
def mnist(): 
    
    def mnistmodel(inputs): 

        """
        Creates and returns neural net model
        """

        x = layers.Conv2D(32, kernel_size=(3, 3),activation='relu', padding='valid',
                          data_format=backend.image_data_format(), input_shape=(224,224,1))(inputs)
        x = layers.Dropout(0.5)(x)
        x = layers.Conv2D(32, kernel_size=(3, 3), strides = (2,2), activation='relu',padding='valid')(x)
        x = layers.MaxPooling2D(pool_size=(2, 2),strides=(2,2))(x)   #112
#         x = layers.BatchNormalization(epsilon=1e-06, mode=0, momentum=0.9, weights=None)(x)
        x = layers.Dropout(0.5)(x)
        x = layers.Conv2D(64, kernel_size=(3, 3), activation='relu',padding='valid')(x)
        x = layers.MaxPooling2D(pool_size=(2, 2),strides=(2,2))(x)   #56
        x = layers.Conv2D(64, kernel_size=(3, 3), activation='relu',padding='valid')(x)
        x = layers.MaxPooling2D(pool_size=(2, 2),strides=(2,2))(x)   #28
        x = layers.Conv2D(128, kernel_size=(3, 3), activation='relu',padding='valid')(x)
        x = layers.MaxPooling2D(pool_size=(2, 2),strides=(2,2))(x)   #14
        x = layers.Conv2D(128, kernel_size=(3, 3), activation='relu',padding='valid')(x)
        x = layers.MaxPooling2D(pool_size=(2, 2),strides=(2,2))(x)   #7,7,128
        x = layers.Flatten()(x)
        x = layers.Dense(128, activation='relu')(x)
        x = layers.Dropout(0.5)(x)
        #x = layers.Dense(self.nclasses, activation='sigmoid')(x)
        x = layers.Dense(5, activation='softmax')(x)
        return x

    model_input = layers.Input(shape=(224,224,1))
    model_output = mnistmodel(model_input)
    model = Model(inputs=model_input, outputs=model_output)
    return model

model= mnist()
BS=2

sgd=optimizers.SGD(lr=0.01,decay=1e-6,momentum=0.9,nesterov=True)
model.compile(loss=categorical_crossentropy,optimizer=sgd,metrics=['accuracy'])

callbacks=[TensorBoard(log_dir= Ipath + 'Tensorboard/TB_resnet50_'+str(100), batch_size=BS),
           ModelCheckpoint(Ipath+ 'Model/M_resnet50_'+str(100),monitor='val_acc',verbose=1,period=1)]  #-{val_accuracy:.2f}

# construct the training image generator for data augmentation
aug = ImageDataGenerator(horizontal_flip=True, rotation_range=20, zoom_range=0.15, 
                         width_shift_range=0.2, height_shift_range=0.2, shear_range=0.
saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 11s 346ms/step - loss: nan - acc: 0.1231 - val_loss: nan - val_acc: 0.0909
# Epoch 80/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0484Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00080: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 360ms/step - loss: nan - acc: 0.0469 - val_loss: nan - val_acc: 0.0909
# Epoch 81/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0952Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00081: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 357ms/step - loss: nan - acc: 0.0923 - val_loss: nan - val_acc: 0.0909
# Epoch 82/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0781Epoch 1/100
# 15/33 [============>.................] - ETA: 6s - loss: nan - acc: 0.0913
# Epoch 00082: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 354ms/step - loss: nan - acc: 0.0758 - val_loss: nan - val_acc: 0.0909
# Epoch 83/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0635Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00083: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 14s 434ms/step - loss: nan - acc: 0.0625 - val_loss: nan - val_acc: 0.0909
# Epoch 84/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.1111Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00084: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 365ms/step - loss: nan - acc: 0.1077 - val_loss: nan - val_acc: 0.0909
# Epoch 85/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0781Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00085: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 13s 404ms/step - loss: nan - acc: 0.0769 - val_loss: nan - val_acc: 0.0909
# Epoch 86/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0781Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00086: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 371ms/step - loss: nan - acc: 0.0758 - val_loss: nan - val_acc: 0.0909
# Epoch 87/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0484Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00087: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 363ms/step - loss: nan - acc: 0.0469 - val_loss: nan - val_acc: 0.0909
# Epoch 88/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0952Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00088: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 371ms/step - loss: nan - acc: 0.0923 - val_loss: nan - val_acc: 0.0909
# Epoch 89/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0625Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00089: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 360ms/step - loss: nan - acc: 0.0606 - val_loss: nan - val_acc: 0.0909
# Epoch 90/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0968Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00090: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 13s 379ms/step - loss: nan - acc: 0.0938 - val_loss: nan - val_acc: 0.0909
# Epoch 91/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0469Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00091: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 13s 379ms/step - loss: nan - acc: 0.0455 - val_loss: nan - val_acc: 0.0909
# Epoch 92/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0806Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00092: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 14s 421ms/step - loss: nan - acc: 0.0938 - val_loss: nan - val_acc: 0.0909
# Epoch 93/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0635Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00093: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 13s 393ms/step - loss: nan - acc: 0.0769 - val_loss: nan - val_acc: 0.0909
# Epoch 94/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0781Epoch 1/100
# 15/33 [============>.................] - ETA: 6s - loss: nan - acc: 0.0913
# Epoch 00094: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 364ms/step - loss: nan - acc: 0.0758 - val_loss: nan - val_acc: 0.0909
# Epoch 95/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0635Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00095: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 359ms/step - loss: nan - acc: 0.0615 - val_loss: nan - val_acc: 0.0909
# Epoch 96/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0794Epoch 1/100
# 15/33 [============>.................] - ETA: 6s - loss: nan - acc: 0.0875
# Epoch 00096: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 356ms/step - loss: nan - acc: 0.0769 - val_loss: nan - val_acc: 0.0909
# Epoch 97/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0794Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00097: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 361ms/step - loss: nan - acc: 0.0769 - val_loss: nan - val_acc: 0.0909
# Epoch 98/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0635Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0875
# Epoch 00098: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 355ms/step - loss: nan - acc: 0.0615 - val_loss: nan - val_acc: 0.0909
# Epoch 99/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0794Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00099: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 359ms/step - loss: nan - acc: 0.0769 - val_loss: nan - val_acc: 0.0909
# Epoch 100/100
# 32/33 [============================>.] - ETA: 0s - loss: nan - acc: 0.0794Epoch 1/100
# 15/33 [============>.................] - ETA: 7s - loss: nan - acc: 0.0913
# Epoch 00100: saving model to /home/malavika/MyHackmain/Model/M_resnet50_100
# 33/33 [==============================] - 12s 363ms/step - loss: nan - acc: 0.0769 - val_loss: nan - val_acc: 0.0909

# %%
# for x,y in aug.flow(XX_train, Y_train_ohe,batch_size=3): 
#     fig=plt.figure(figsize=(15,7))
#     for i in range(0, len(x)):
#         plt.subplot(330 + 1 + i)
# #         if x[i] : 
#         Tx=x[i].T[0]
#         print(cl[np.nonzero(y[i])[0][0]+1])
#         plt.imshow(Tx)
#     plt.show()
#     if len(x)<3: 
#         break

# %%
pwd
# Out:
# '/home/malavika/MyHackmain/MyHack'
